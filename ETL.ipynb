# %%
#importar libreria 
import pandas as pd

# %% [markdown]
# ## Extracción-Transformación-Carga

# %% [markdown]
# ### Crecimiento del PIB(% anual)

# %%
#Leer un archivo CSV utilizando la librería pandas
df = pd.read_csv(r"Dataset/Crecimiento del PIB (% anual).csv")

# %%
df
# Out:
#         Country Name Country Code                 Indicator Name
# 0              Aruba          ABW  Crecimiento del PIB (% anual)  \
# 1                NaN          AFE  Crecimiento del PIB (% anual)
# 2         Afganistán          AFG  Crecimiento del PIB (% anual)
# 3                NaN          AFW  Crecimiento del PIB (% anual)
# 4             Angola          AGO  Crecimiento del PIB (% anual)
# ..               ...          ...                            ...
# 261           Kosovo          XKX  Crecimiento del PIB (% anual)
# 262  Yemen, Rep. del          YEM  Crecimiento del PIB (% anual)
# 263        Sudáfrica          ZAF  Crecimiento del PIB (% anual)
# 264           Zambia          ZMB  Crecimiento del PIB (% anual)
# 265         Zimbabwe          ZWE  Crecimiento del PIB (% anual)
#
#         Indicator Code  1960      1961      1962      1963       1964
# 0    NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN        NaN  \
# ...

# %%
# Filtrar columndas por nombre y por años de interes (2000-2021)
df = df[['Country Name', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009','2010', '2011', '2012','2013','2014', '2015','2016', '2017', '2018','2019', '2020', '2021']]

# %%
# Filtrar filas por los paises de interes
paises_de_interes = ["México" , "Estados Unidos" , "Guatemala" , "Honduras" , "El Salvador" , "Colombia" , "Chile" , "Argentina" , "Brasil" , "Uruguay"]
mascara = df["Country Name"].isin(paises_de_interes)
PIB_anual = df[mascara]

# %%
PIB_anual
# Out:
#        Country Name      2000      2001       2002      2003      2004
# 9         Argentina -0.788999 -4.408840 -10.894485  8.837041  9.029573  \
# 29           Brasil  4.387949  1.389896   3.053462  1.140829  5.759965
# 39            Chile  4.971621  3.154035   3.202799  4.723245  6.674254
# 45         Colombia  2.924861  1.677898   2.503980  3.918272  5.333022
# 92        Guatemala  3.608869  2.332575   3.839287  2.560378  3.137917
# 97         Honduras  7.291288  2.723193   3.754338  4.547038  6.232303
# 154          México  4.942454 -0.404390  -0.039844  1.446383  3.920591
# 211     El Salvador  1.127907  0.879614   1.572918  1.565393  0.889404
# 250         Uruguay -1.929931 -3.844130  -7.732007  0.805284  5.004160
# 251  Estados Unidos  4.077159  0.954339   1.695943  2.796209  3.852553
#
#          2005      2006      2007      2008  ...      2012      2013
# 9    8.851660  8.047152  9.007651  4.057233  ... -1.026420  2.405324  \
# ...

# %% [markdown]
# ### Crecimiento del PIB per cápita

# %%
df = pd.read_csv(r"Dataset/Crecimiento del PIB per cápita (% anual).csv")

# %%
df
# Out:
#         Country Name Country Code                            Indicator Name
# 0              Aruba          ABW  Crecimiento del PIB per cápita (% anual)  \
# 1                NaN          AFE  Crecimiento del PIB per cápita (% anual)
# 2         Afganistán          AFG  Crecimiento del PIB per cápita (% anual)
# 3                NaN          AFW  Crecimiento del PIB per cápita (% anual)
# 4             Angola          AGO  Crecimiento del PIB per cápita (% anual)
# ..               ...          ...                                       ...
# 261           Kosovo          XKX  Crecimiento del PIB per cápita (% anual)
# 262  Yemen, Rep. del          YEM  Crecimiento del PIB per cápita (% anual)
# 263        Sudáfrica          ZAF  Crecimiento del PIB per cápita (% anual)
# 264           Zambia          ZMB  Crecimiento del PIB per cápita (% anual)
# 265         Zimbabwe          ZWE  Crecimiento del PIB per cápita (% anual)
#
# ...

# %%
# Filtrar columndas por nombre y por años de interes (2000-2021)
df = df[['Country Name', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009','2010', '2011', '2012','2013','2014', '2015','2016', '2017', '2018','2019', '2020', '2021']]

# %%
# Filtrar filas por los paises de interes
paises_de_interes = ["México" , "Estados Unidos" , "Guatemala" , "Honduras" , "El Salvador" , "Colombia" , "Chile" , "Argentina" , "Brasil" , "Uruguay"]
mascara = df["Country Name"].isin(paises_de_interes)
PIB_percapita = df[mascara]

# %%
PIB_percapita
# Out:
#        Country Name      2000      2001       2002      2003      2004
# 9         Argentina -1.906987 -5.453797 -11.845950  7.719230  7.928157  \
# 29           Brasil  2.970911  0.059649   1.760243 -0.051286  4.561782
# 39            Chile  3.772357  2.009937   2.086111  3.631566  5.616340
# 45         Colombia  1.271083  0.088484   0.942693  2.390448  3.839378
# 92        Guatemala  1.117529 -0.096568   1.480389  0.348008  0.968363
# 97         Honduras  4.400412  0.002040   1.063681  1.905403  3.620511
# 154          México  3.292692 -1.928317  -1.548198 -0.051365  2.404487
# 211     El Salvador  0.540163  0.380732   1.181244  1.302938  0.742207
# 250         Uruguay -2.324955 -4.097997  -7.885543  0.690751  4.890119
# 251  Estados Unidos  2.925441 -0.039920   0.756774  1.916480  2.895848
#
#          2005      2006      2007      2008  ...      2012      2013
# 9    7.732497  6.934982  7.916211  3.029785  ... -2.145284  1.265685  \
# ...

# %% [markdown]
# ### Migración neta

# %%
df = pd.read_csv(r"Dataset/migrantes neto.csv")

# %%
# Eliminar columnas fuera del rango de año de interes (2000-2021) y columnas "Indicator Name", "Indicator Code" , "Unnamed: 66"
coldrop = [str(year) for year in range(1960,2000)]
df = df.drop(coldrop, axis=1)
df = df.drop(["Indicator Name", "Indicator Code" , "Unnamed: 66"] , axis= 1)

# %%
# Filtrar filas por los paises de interes
paises_de_interes = ["México" , "Estados Unidos" , "Guatemala" , "Honduras" , "El Salvador" , "Colombia" , "Chile" , "Argentina" , "Brasil" , "Uruguay"]
mascara = df["Country Name"].isin(paises_de_interes)
migracion_neta = df[mascara]

# %%
migracion_neta
# Out:
#        Country Name Country Code       2000       2001       2002       2003
# 9         Argentina          ARG   -22770.0   -22787.0   -22668.0   -22353.0  \
# 29           Brasil          BRA    -1761.0     3453.0     6018.0   -16908.0
# 39            Chile          CHL     5790.0     6720.0     7828.0     9266.0
# 45         Colombia          COL   -31116.0   -27618.0   -24379.0   -33007.0
# 92        Guatemala          GTM   -66153.0   -59249.0   -55245.0   -54666.0
# 97         Honduras          HND   -10762.0    -9749.0    -8815.0    -7986.0
# 154          México          MEX  -356430.0  -348349.0  -324106.0  -332396.0
# 211     El Salvador          SLV   -97219.0   -93347.0   -92034.0   -91736.0
# 250         Uruguay          URY   -11074.0   -14628.0   -16958.0   -17099.0
# 251  Estados Unidos          USA  1479676.0  1335725.0  1168499.0  1074728.0
#
#           2004       2005       2006       2007  ...       2012       2013
# ...

# %% [markdown]
# ### Volumen de migrantes (% de la población)

# %%
df = pd.read_csv(r"Dataset/migrantes (% de la población).csv")

# %%
df.head()
# Out:
#   Country Name Country Code
# 0        Aruba          ABW  \
# 1          NaN          AFE
# 2   Afganistán          AFG
# 3          NaN          AFW
# 4       Angola          AGO
#
#                                       Indicator Name  Indicator Code  1960
# 0  Volúmenes internacionales de migrantes (% de l...  SM.POP.TOTL.ZS   NaN  \
# 1  Volúmenes internacionales de migrantes (% de l...  SM.POP.TOTL.ZS   NaN
# 2  Volúmenes internacionales de migrantes (% de l...  SM.POP.TOTL.ZS   NaN
# 3  Volúmenes internacionales de migrantes (% de l...  SM.POP.TOTL.ZS   NaN
# 4  Volúmenes internacionales de migrantes (% de l...  SM.POP.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2013  2014       2015  2016  2017  2018
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN  34.762102   NaN   NaN   NaN  \
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   1.734292   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   1.175547   NaN   NaN   NaN
# ...

# %%
# Eliminar columnas fuera del rango de año de interes (2000-2021) y columnas "Indicator Name", "Indicator Code" , "Unnamed: 66"
coldrop = [str(year) for year in range(1960,2000)]
df = df.drop(coldrop, axis=1)
df = df.drop(["Indicator Name", "Indicator Code" , "Unnamed: 66"] , axis= 1)

# %%
# Filtrar filas por los paises de interes
paises_de_interes = ["México" , "Estados Unidos" , "Guatemala" , "Honduras" , "El Salvador" , "Colombia" , "Chile" , "Argentina" , "Brasil" , "Uruguay"]
mascara = df["Country Name"].isin(paises_de_interes)
porc_migrantes = df[mascara]

# %%
porc_migrantes
# Out:
#        Country Name Country Code       2000  2001  2002  2003  2004
# 9         Argentina          ARG   4.156300   NaN   NaN   NaN   NaN  \
# 29           Brasil          BRA   0.389448   NaN   NaN   NaN   NaN
# 39            Chile          CHL   1.168935   NaN   NaN   NaN   NaN
# 45         Colombia          COL   0.271283   NaN   NaN   NaN   NaN
# 92        Guatemala          GTM   0.411673   NaN   NaN   NaN   NaN
# 97         Honduras          HND   0.455881   NaN   NaN   NaN   NaN
# 154          México          MEX   0.523352   NaN   NaN   NaN   NaN
# 211     El Salvador          SLV   0.545662   NaN   NaN   NaN   NaN
# 250         Uruguay          URY   2.675836   NaN   NaN   NaN   NaN
# 251  Estados Unidos          USA  12.306319   NaN   NaN   NaN   NaN
#
#           2005  2006  2007  ...  2012  2013  2014       2015  2016  2017
# 9     4.274025   NaN   NaN  ...   NaN   NaN   NaN   4.805292   NaN   NaN  \
# ...

# %% [markdown]
# Esta base de datos posee una gran cantidad de valores nulos por lo que se evaluará su uso en nuestro proyecto

# %% [markdown]
# ### Volumen de migrantes, total

# %%
df = pd.read_csv(r"Dataset/migrantes total.csv")

# %%
df.head()
# Out:
#   Country Name Country Code                                 Indicator Name
# 0        Aruba          ABW  Volúmenes internacionales de migrantes, total  \
# 1          NaN          AFE  Volúmenes internacionales de migrantes, total
# 2   Afganistán          AFG  Volúmenes internacionales de migrantes, total
# 3          NaN          AFW  Volúmenes internacionales de migrantes, total
# 4       Angola          AGO  Volúmenes internacionales de migrantes, total
#
#   Indicator Code      1960  1961  1962  1963  1964     1965  ...  2013  2014
# 0    SM.POP.TOTL    7893.0   NaN   NaN   NaN   NaN   7677.0  ...   NaN   NaN  \
# 1    SM.POP.TOTL       NaN   NaN   NaN   NaN   NaN      NaN  ...   NaN   NaN
# 2    SM.POP.TOTL   46468.0   NaN   NaN   NaN   NaN  49535.0  ...   NaN   NaN
# 3    SM.POP.TOTL       NaN   NaN   NaN   NaN   NaN      NaN  ...   NaN   NaN
# 4    SM.POP.TOTL  122089.0   NaN   NaN   NaN   NaN  77075.0  ...   NaN   NaN
#
# ...

# %%
# Eliminar columnas fuera del rango de año de interes (2000-2021) y columnas "Indicator Name", "Indicator Code" , "Unnamed: 66"
coldrop = [str(year) for year in range(1960,2000)]
df = df.drop(coldrop, axis=1)
df = df.drop(["Indicator Name", "Indicator Code" , "Unnamed: 66"] , axis= 1)

# %%
# Filtrar filas por los paises de interes
paises_de_interes = ["México" , "Estados Unidos" , "Guatemala" , "Honduras" , "El Salvador" , "Colombia" , "Chile" , "Argentina" , "Brasil" , "Uruguay"]
mascara = df["Country Name"].isin(paises_de_interes)
total_migrantes = df[mascara]

# %%
total_migrantes
# Out:
#        Country Name Country Code        2000  2001  2002  2003  2004
# 9         Argentina          ARG   1540219.0   NaN   NaN   NaN   NaN  \
# 29           Brasil          BRA    684596.0   NaN   NaN   NaN   NaN
# 39            Chile          CHL    177332.0   NaN   NaN   NaN   NaN
# 45         Colombia          COL    109609.0   NaN   NaN   NaN   NaN
# 92        Guatemala          GTM     48119.0   NaN   NaN   NaN   NaN
# 97         Honduras          HND     28461.0   NaN   NaN   NaN   NaN
# 154          México          MEX    538051.0   NaN   NaN   NaN   NaN
# 211     El Salvador          SLV     31713.0   NaN   NaN   NaN   NaN
# 250         Uruguay          URY     88871.0   NaN   NaN   NaN   NaN
# 251  Estados Unidos          USA  34814053.0   NaN   NaN   NaN   NaN
#
#            2005  2006  2007  ...  2012  2013  2014        2015  2016  2017
# 9     1673088.0   NaN   NaN  ...   NaN   NaN   NaN   2086302.0   NaN   NaN  \
# ...

# %% [markdown]
# Esta base de datos posee una gran cantidad de valores nulos por lo que se evaluará su uso en nuestro proyecto

# %% [markdown]
# ### % de Desempleo

# %%
df = pd.read_csv("Dataset/desempleo.csv")

# %%
df
# Out:
#         Country Name Country Code
# 0              Aruba          ABW  \
# 1                NaN          AFE
# 2         Afganistán          AFG
# 3                NaN          AFW
# 4             Angola          AGO
# ..               ...          ...
# 261           Kosovo          XKX
# 262  Yemen, Rep. del          YEM
# 263        Sudáfrica          ZAF
# 264           Zambia          ZMB
# 265         Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960
# 0    Desempleo, total (% de la población activa tot...  SL.UEM.TOTL.ZS   NaN  \
# 1    Desempleo, total (% de la población activa tot...  SL.UEM.TOTL.ZS   NaN
# 2    Desempleo, total (% de la población activa tot...  SL.UEM.TOTL.ZS   NaN
# 3    Desempleo, total (% de la población activa tot...  SL.UEM.TOTL.ZS   NaN
# 4    Desempleo, total (% de la población activa tot...  SL.UEM.TOTL.ZS   NaN
# ..                                                 ...             ...   ...
# ...

# %%
#Filtrar columnas con datos desde el año 2000
df = df[['Country Name','2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009','2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']]

# %%
# Filtrar filas por los paises de interes
paises_de_interes = ["México" , "Estados Unidos" , "Guatemala" , "Honduras" , "El Salvador" , "Colombia" , "Chile" , "Argentina" , "Brasil" , "Uruguay"]
mascara = df["Country Name"].isin(paises_de_interes)
desempleo = df[mascara]

# %%
desempleo
# Out:
#        Country Name    2000    2001    2002   2003   2004    2005    2006
# 9         Argentina  15.000  17.320  19.590  15.36  13.52  11.510  10.080  \
# 29           Brasil  10.530  10.650  10.640  11.17  10.07  10.550   9.690
# 39            Chile  10.490  10.390  10.170   9.77  10.16   9.340   9.020
# 45         Colombia  20.520  15.040  15.630  14.19  13.72  11.870  10.963
# 92        Guatemala   2.750   2.793   2.767   2.81   2.97   3.053   3.082
# 97         Honduras   3.855   4.000   4.020   5.30   5.99   4.910   3.570
# 154          México   2.650   2.630   3.000   3.46   3.94   3.560   3.570
# 211     El Salvador   6.960   6.960   6.200   6.90   6.80   7.220   6.570
# 250         Uruguay  12.630  15.050  16.650  16.66  12.98  12.010  10.840
# 251  Estados Unidos   3.990   4.730   5.780   5.99   5.53   5.080   4.620
#
#       2007    2008  ...  2012  2013  2014   2015    2016   2017   2018   2019
# ...

# %% [markdown]
# ### Remesas de trabajadores como % del PIB

# %%
df = pd.read_csv("Dataset/remesas recibidas.csv")

# %%
df
# Out:
#         Country Name Country Code
# 0              Aruba          ABW  \
# 1                NaN          AFE
# 2         Afganistán          AFG
# 3                NaN          AFW
# 4             Angola          AGO
# ..               ...          ...
# 261           Kosovo          XKX
# 262  Yemen, Rep. del          YEM
# 263        Sudáfrica          ZAF
# 264           Zambia          ZMB
# 265         Zimbabwe          ZWE
#
#                                         Indicator Name        Indicator Code
# 0    Remesas de trabajadores y compensación de empl...  BX.TRF.PWKR.DT.GD.ZS  \
# 1    Remesas de trabajadores y compensación de empl...  BX.TRF.PWKR.DT.GD.ZS
# 2    Remesas de trabajadores y compensación de empl...  BX.TRF.PWKR.DT.GD.ZS
# 3    Remesas de trabajadores y compensación de empl...  BX.TRF.PWKR.DT.GD.ZS
# 4    Remesas de trabajadores y compensación de empl...  BX.TRF.PWKR.DT.GD.ZS
# ..                                                 ...                   ...
# ...

# %%
#Filtrar columnas con datos desde el año 2000
df = df[['Country Name', 'Country Code', 'Indicator Name','2000','2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009','2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']]

# %%
# Filtrar filas por los paises de interes
paises_de_interes = ["México" , "Estados Unidos" , "Guatemala" , "Honduras" , "El Salvador" , "Colombia" , "Chile" , "Argentina" , "Brasil" , "Uruguay"]
mascara = df["Country Name"].isin(paises_de_interes)
remesas = df[mascara]

# %%
remesas
# Out:
#        Country Name Country Code
# 9         Argentina          ARG  \
# 29           Brasil          BRA
# 39            Chile          CHL
# 45         Colombia          COL
# 92        Guatemala          GTM
# 97         Honduras          HND
# 154          México          MEX
# 211     El Salvador          SLV
# 250         Uruguay          URY
# 251  Estados Unidos          USA
#
#                                         Indicator Name       2000       2001
# 9    Remesas de trabajadores y compensación de empl...   0.030381   0.070563  \
# 29   Remesas de trabajadores y compensación de empl...   0.205904   0.258739
# 39   Remesas de trabajadores y compensación de empl...   0.016997   0.016639
# 45   Remesas de trabajadores y compensación de empl...   1.611951   2.093801
# 92   Remesas de trabajadores y compensación de empl...   3.090909   3.443339
# 97   Remesas de trabajadores y compensación de empl...   6.602495   7.978403
# ...

# %% [markdown]
# ### índice de Gini

# %%
df = pd.read_csv("Dataset/Indice gini.csv")

# %%
df
# Out:
#         Country Name Country Code  Indicator Name Indicator Code  1960  1961
# 0              Aruba          ABW  Índice de Gini    SI.POV.GINI   NaN   NaN  \
# 1                NaN          AFE  Índice de Gini    SI.POV.GINI   NaN   NaN
# 2         Afganistán          AFG  Índice de Gini    SI.POV.GINI   NaN   NaN
# 3                NaN          AFW  Índice de Gini    SI.POV.GINI   NaN   NaN
# 4             Angola          AGO  Índice de Gini    SI.POV.GINI   NaN   NaN
# ..               ...          ...             ...            ...   ...   ...
# 261           Kosovo          XKX  Índice de Gini    SI.POV.GINI   NaN   NaN
# 262  Yemen, Rep. del          YEM  Índice de Gini    SI.POV.GINI   NaN   NaN
# 263        Sudáfrica          ZAF  Índice de Gini    SI.POV.GINI   NaN   NaN
# 264           Zambia          ZMB  Índice de Gini    SI.POV.GINI   NaN   NaN
# 265         Zimbabwe          ZWE  Índice de Gini    SI.POV.GINI   NaN   NaN
#
# ...

# %%
#Filtrar columnas con datos desde el año 2000
df = df[['Country Name', 'Country Code', 'Indicator Name','2000','2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009','2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']]

# %%
# Filtrar filas por los paises de interes
paises_de_interes = ["México" , "Estados Unidos" , "Guatemala" , "Honduras" , "El Salvador" , "Colombia" , "Chile" , "Argentina" , "Brasil" , "Uruguay"]
mascara = df["Country Name"].isin(paises_de_interes)
gini = df[mascara]

# %%
gini
# Out:
#        Country Name Country Code  Indicator Name  2000  2001  2002  2003
# 9         Argentina          ARG  Índice de Gini  51.1  53.3  53.8  50.9  \
# 29           Brasil          BRA  Índice de Gini   NaN  58.4  58.1  57.6
# 39            Chile          CHL  Índice de Gini  52.8   NaN   NaN  51.5
# 45         Colombia          COL  Índice de Gini  58.7  57.5  56.0  53.6
# 92        Guatemala          GTM  Índice de Gini  54.2   NaN   NaN   NaN
# 97         Honduras          HND  Índice de Gini   NaN  55.4  55.7  58.1
# 154          México          MEX  Índice de Gini  52.6   NaN  50.1   NaN
# 211     El Salvador          SLV  Índice de Gini  51.5  51.4  51.9  50.5
# 250         Uruguay          URY  Índice de Gini   NaN   NaN   NaN   NaN
# 251  Estados Unidos          USA  Índice de Gini  40.1  40.6  40.4  40.8
#
#      2004  2005  2006  ...  2012  2013  2014  2015  2016  2017  2018  2019
# 9    48.4  47.7  46.3  ...  41.3  40.9  41.6   NaN  42.0  41.1  41.3  42.9  \
# ...
